# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sb
# %matplotlib inline 

address1 = 'C:/Users/harsh/Desktop/Summer Projects/TitanicKaggle/train_df.csv'
address2 = 'C:/Users/harsh/Desktop/Summer Projects/TitanicKaggle/test_df.csv'

traindf = pd.read_csv(address1)
testdf = pd.read_csv(address2)

# %%
testdf.head()
# Out:
#    Pclass  Sex   Age  Relatives  Cabin_ind
# 0       3    0  34.5          0          0
# 1       3    1  47.0          1          0
# 2       2    0  62.0          0          0
# 3       3    0  27.0          0          0
# 4       3    1  22.0          2          0

# %%
address_temp = 'C:/Users/harsh/Desktop/Summer Projects/TitanicKaggle/train.csv'
tempdf = pd.read_csv(address_temp)

address_temp2 = 'C:/Users/harsh/Desktop/Summer Projects/TitanicKaggle/test.csv'
temp2 = pd.read_csv(address_temp2)

traindf['Fare'] = tempdf.Fare
testdf['Fare'] = temp2.Fare
testdf.head()
# Out:
#    Pclass  Sex   Age  Relatives  Cabin_ind     Fare
# 0       3    0  34.5          0          0   7.8292
# 1       3    1  47.0          1          0   7.0000
# 2       2    0  62.0          0          0   9.6875
# 3       3    0  27.0          0          0   8.6625
# 4       3    1  22.0          2          0  12.2875

# %%
traindf.head()
# Out:
#    Survived  Pclass  Sex   Age  Relatives  Cabin_ind     Fare
# 0         0       3    0  22.0          1          0   7.2500
# 1         1       1    1  38.0          1          1  71.2833
# 2         1       3    1  26.0          0          0   7.9250
# 3         1       1    1  35.0          1          1  53.1000
# 4         0       3    0  35.0          0          0   8.0500

# %%
from sklearn.model_selection import train_test_split

features = traindf.drop('Survived', axis=1)
labels = traindf['Survived']

x_train, x_test, y_train, y_test = train_test_split(features, labels, test_size=0.4, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size=0.5, random_state=42)

# %%
for data in [y_train, y_val, y_test]:
    print(round(len(data)/len(labels), 2))
# Out:
# 0.6
# 0.2
# 0.2

# %%
from sklearn.linear_model import LogisticRegression

#note the rather limited list of hyperparamters (compared to other algorithms)
LogisticRegression()
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
dir(LogisticRegression)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_estimator_type',
#  '_get_param_names',
#  '_get_tags',
#  '_predict_proba_lr',
#  'decision_function',
#  'densify',
#  'fit',
#  'get_params',
#  'predict',
#  'predict_log_proba',
#  'predict_proba',
#  'score',
#  'set_params',
#  'sparsify']

# %%
# For saving a model 
import joblib 
from sklearn.model_selection import GridSearchCV

def print_results(results):
    print('BEST PARAMS: {}\n'.format(results.best_params_))
    
    means = results.cv_results_['mean_test_score']
    stds = results.cv_results_['std_test_score']
    for mean, stds, params in zip(means, stds, results.cv_results_['params']):
        print('{} (+/-{}) for {}'.format(round(mean, 3), round(stds * 2, 3), params))

# %%
# Preparing a model and dictionary for GridSearchCV for analysing different hyperparameter combinations

# Logistic Regression - algo for binary algorithms
lr_model = LogisticRegression() 
parameters = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000]
}

#Cross validatioon
cv = GridSearchCV(lr_model, parameters, cv=5)
cv.fit(x_train, y_train.values.ravel())

print_results(cv)

#High regularization (low c value) causes the model to underfit, so it doesnt perform very well
# Out:
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# BEST PARAMS: {'C': 1}
#
# 0.678 (+/-0.092) for {'C': 0.001}
# 0.704 (+/-0.099) for {'C': 0.01}
# 0.796 (+/-0.13) for {'C': 0.1}
# 0.798 (+/-0.123) for {'C': 1}
# 0.794 (+/-0.118) for {'C': 10}
# 0.794 (+/-0.118) for {'C': 100}
# 0.794 (+/-0.118) for {'C': 1000}
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
cv.best_estimator_
# Out:
# LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
#write out the model 
joblib.dump(cv.best_estimator_, 'C:/Users/harsh/Desktop/Summer Projects/TitanicKaggle/models/LR_model.pkl')
# Out:
# ['C:/Users/harsh/Desktop/Summer Projects/TitanicKaggle/models/LR_model.pkl']

# %%
from sklearn.svm import SVC

SVC()

# Look at 'kernel' and 'C' hyperparameters
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
# Kernel trick optimization and c parameter optimization 
svc = SVC()
parameters = {
    'kernel' : ['linear', 'rbf'],
    'C' : [0.1, 1, 10]
}

cv = GridSearchCV(svc, parameters, cv=5)
cv.fit(x_train, y_train.values.ravel())

print_results(cv)

# Notice, that the C pattern does not have any effect when the kernel is linear
# Out:
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# BEST PARAMS: {'C': 0.1, 'kernel': 'linear'}
#
# 0.796 (+/-0.116) for {'C': 0.1, 'kernel': 'linear'}
# 0.624 (+/-0.005) for {'C': 0.1, 'kernel': 'rbf'}
# 0.796 (+/-0.116) for {'C': 1, 'kernel': 'linear'}
# 0.667 (+/-0.081) for {'C': 1, 'kernel': 'rbf'}
# 0.796 (+/-0.116) for {'C': 10, 'kernel': 'linear'}
# 0.691 (+/-0.073) for {'C': 10, 'kernel': 'rbf'}

# %%
# Write out SVM model 

joblib.dump(cv.best_estimator_, 'C:/Users/harsh/Desktop/Summer Projects/TitanicKaggle/models/SVM_model.pkl')
# Out:
# ['C:/Users/harsh/Desktop/Summer Projects/TitanicKaggle/models/SVM_model.pkl']

# %%
# To use MultiLayer Perceptron, import two classes

from sklearn.neural_network import MLPRegressor, MLPClassifier

MLPRegressor()
# Out:
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#              beta_2=0.999, early_stopping=False, epsilon=1e-08,
#              hidden_layer_sizes=(100,), learning_rate='constant',
#              learning_rate_init=0.001, max_iter=200, momentum=0.9,
#              n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#              random_state=None, shuffle=True, solver='adam', tol=0.0001,
#              validation_fraction=0.1, verbose=False, warm_start=False)

# %%
MLPClassifier()
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=None, shuffle=True, solver='adam', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
mlp = MLPClassifier() 
# Exploring models with only one hidden layer 'hidden_layer_sizes' : (n = number of nodes, m = number of layers)
parameters = {
    'hidden_layer_sizes' : [(10, 1), (50, 1), (100, 1)],
    'activation' : ['relu', 'tanh', 'logistic'], 
    'learning_rate' : ['constant', 'invscaling', 'adaptive']
}

cv = GridSearchCV(mlp, parameters, cv=5)
cv.fit(x_train, y_train.values.ravel())

print_results(cv)
# Out:
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# BEST PARAMS: {'activation': 'tanh', 'hidden_layer_sizes': (100, 1), 'learning_rate': 'invscaling'}
#
# 0.575 (+/-0.197) for {'activation': 'relu', 'hidden_layer_sizes': (10, 1), 'learning_rate': 'constant'}
# 0.637 (+/-0.046) for {'activation': 'relu', 'hidden_layer_sizes': (10, 1), 'learning_rate': 'invscaling'}
# 0.68 (+/-0.128) for {'activation': 'relu', 'hidden_layer_sizes': (10, 1), 'learning_rate': 'adaptive'}
# 0.597 (+/-0.39) for {'activation': 'relu', 'hidden_layer_sizes': (50, 1), 'learning_rate': 'constant'}
# 0.8 (+/-0.105) for {'activation': 'relu', 'hidden_layer_sizes': (50, 1), 'learning_rate': 'invscaling'}
# 0.62 (+/-0.306) for {'activation': 'relu', 'hidden_layer_sizes': (50, 1), 'learning_rate': 'adaptive'}
# 0.562 (+/-0.307) for {'activation': 'relu', 'hidden_layer_sizes': (100, 1), 'learning_rate': 'constant'}
# 0.545 (+/-0.292) for {'activation': 'relu', 'hidden_layer_sizes': (100, 1), 'learning_rate': 'invscaling'}
# 0.575 (+/-0.371) for {'activation': 'relu', 'hidden_layer_sizes': (100, 1), 'learning_rate': 'adaptive'}
# 0.695 (+/-0.083) for {'activation': 'tanh', 'hidden_layer_sizes': (10, 1), 'learning_rate': 'constant'}
# 0.684 (+/-0.126) for {'activation': 'tanh', 'hidden_layer_sizes': (10, 1), 'learning_rate': 'invscaling'}
# 0.657 (+/-0.298) for {'activation': 'tanh', 'hidden_layer_sizes': (10, 1), 'learning_rate': 'adaptive'}
# 0.8 (+/-0.125) for {'activation': 'tanh', 'hidden_layer_sizes': (50, 1), 'learning_rate': 'constant'}
# 0.77 (+/-0.074) for {'activation': 'tanh', 'hidden_layer_sizes': (50, 1), 'learning_rate': 'invscaling'}
# 0.79 (+/-0.122) for {'activation': 'tanh', 'hidden_layer_sizes': (50, 1), 'learning_rate': 'adaptive'}
# 0.785 (+/-0.15) for {'activation': 'tanh', 'hidden_layer_sizes': (100, 1), 'learning_rate': 'constant'}
# 0.815 (+/-0.123) for {'activation': 'tanh', 'hidden_layer_sizes': (100, 1), 'learning_rate': 'invscaling'}
# 0.76 (+/-0.077) for {'activation': 'tanh', 'hidden_layer_sizes': (100, 1), 'learning_rate': 'adaptive'}
# 0.627 (+/-0.028) for {'activation': 'logistic', 'hidden_layer_sizes': (10, 1), 'learning_rate': 'constant'}
# 0.588 (+/-0.216) for {'activation': 'logistic', 'hidden_layer_sizes': (10, 1), 'learning_rate': 'invscaling'}
# 0.644 (+/-0.064) for {'activation': 'logistic', 'hidden_layer_sizes': (10, 1), 'learning_rate': 'adaptive'}
# 0.648 (+/-0.091) for {'activation': 'logistic', 'hidden_layer_sizes': (50, 1), 'learning_rate': 'constant'}
# 0.648 (+/-0.097) for {'activation': 'logistic', 'hidden_layer_sizes': (50, 1), 'learning_rate': 'invscaling'}
# 0.635 (+/-0.299) for {'activation': 'logistic', 'hidden_layer_sizes': (50, 1), 'learning_rate': 'adaptive'}
# 0.708 (+/-0.148) for {'activation': 'logistic', 'hidden_layer_sizes': (100, 1), 'learning_rate': 'constant'}
# 0.652 (+/-0.115) for {'activation': 'logistic', 'hidden_layer_sizes': (100, 1), 'learning_rate': 'invscaling'}
# 0.614 (+/-0.266) for {'activation': 'logistic', 'hidden_layer_sizes': (100, 1), 'learning_rate': 'adaptive'}
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
# For all estimators, models with only 10 hidden nodes appears to be too simple and is underfitting
# relu and tanh appear to generate better results for this specific problems 
cv.best_estimator_
# Out:
# MLPClassifier(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100, 1), learning_rate='invscaling',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=None, shuffle=True, solver='adam', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
joblib.dump(cv.best_estimator_, 'C:/Users/harsh/Desktop/Summer Projects/TitanicKaggle/models/MLP_model.pkl')
# Out:
# ['C:/Users/harsh/Desktop/Summer Projects/TitanicKaggle/models/MLP_model.pkl']

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor

RandomForestClassifier()
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators='warn',
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
RandomForestRegressor()
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators='warn',
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
rf = RandomForestClassifier() 
parameters = {
    'n_estimators': [5, 50, 250],
    'max_depth': [2, 4, 8, 16, 32, None]
}

cv = GridSearchCV(rf, parameters, cv=5)
cv.fit(x_train, y_train.values.ravel())

print_results(cv)

# The worst ones are the ones with 5 estimators, max depth of 4, 8 do quite well
# After that, it starts overfitting
# Out:
# BEST PARAMS: {'max_depth': 8, 'n_estimators': 50}
#
# 0.76 (+/-0.109) for {'max_depth': 2, 'n_estimators': 5}
# 0.801 (+/-0.109) for {'max_depth': 2, 'n_estimators': 50}
# 0.8 (+/-0.131) for {'max_depth': 2, 'n_estimators': 250}
# 0.818 (+/-0.114) for {'max_depth': 4, 'n_estimators': 5}
# 0.83 (+/-0.1) for {'max_depth': 4, 'n_estimators': 50}
# 0.828 (+/-0.114) for {'max_depth': 4, 'n_estimators': 250}
# 0.813 (+/-0.107) for {'max_depth': 8, 'n_estimators': 5}
# 0.835 (+/-0.068) for {'max_depth': 8, 'n_estimators': 50}
# 0.813 (+/-0.089) for {'max_depth': 8, 'n_estimators': 250}
# 0.788 (+/-0.054) for {'max_depth': 16, 'n_estimators': 5}
# 0.811 (+/-0.03) for {'max_depth': 16, 'n_estimators': 50}
# 0.809 (+/-0.028) for {'max_depth': 16, 'n_estimators': 250}
# 0.796 (+/-0.026) for {'max_depth': 32, 'n_estimators': 5}
# 0.809 (+/-0.025) for {'max_depth': 32, 'n_estimators': 50}
# 0.805 (+/-0.03) for {'max_depth': 32, 'n_estimators': 250}
# 0.792 (+/-0.058) for {'max_depth': None, 'n_estimators': 5}
# 0.818 (+/-0.026) for {'max_depth': None, 'n_estimators': 50}
# 0.807 (+/-0.023) for {'max_depth': None, 'n_estimators': 250}
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
joblib.dump(cv.best_estimator_, 'C:/Users/harsh/Desktop/Summer Projects/TitanicKaggle/models/RF_model.pkl')
# Out:
# ['C:/Users/harsh/Desktop/Summer Projects/TitanicKaggle/models/RF_model.pkl']

# %%
from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor 

GradientBoostingClassifier()
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='auto',
#                            random_state=None, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
GradientBoostingRegressor()
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                           learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='auto',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
gb = GradientBoostingClassifier()
parameters = {
    'n_estimators': [5, 50, 250, 500],
    'max_depth': [1, 3, 5, 7, 9],
    'learning_rate': [0.01, 0.1, 1, 10, 100]
}

cv = GridSearchCV(gb, parameters, cv=5)
cv.fit(x_train, y_train.values.ravel())

print_results(cv)
# Notice, high learning rate is generating very poor results all the way across 
# models using only 5 decision trees is consistently generating the worst results
# Out:
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# BEST PARAMS: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
#
# 0.624 (+/-0.005) for {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 5}
# 0.796 (+/-0.116) for {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 50}
# 0.796 (+/-0.116) for {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 250}
# 0.811 (+/-0.118) for {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 500}
# 0.624 (+/-0.005) for {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 5}
# 0.811 (+/-0.071) for {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}
# 0.83 (+/-0.076) for {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 250}
# 0.841 (+/-0.079) for {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# 0.624 (+/-0.005) for {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 5}
# 0.82 (+/-0.052) for {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}
# 0.82 (+/-0.039) for {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 250}
# 0.83 (+/-0.044) for {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500}
# 0.624 (+/-0.005) for {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 5}
# 0.816 (+/-0.05) for {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}
# 0.816 (+/-0.028) for {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 250}
# 0.803 (+/-0.021) for {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 500}
# 0.624 (+/-0.005) for {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 5}
# 0.803 (+/-0.06) for {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 50}
# 0.805 (+/-0.027) for {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 250}
# 0.779 (+/-0.033) for {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 500}
# 0.796 (+/-0.116) for {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 5}
# 0.815 (+/-0.12) for {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 50}
# 0.818 (+/-0.112) for {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 250}
# 0.828 (+/-0.093) for {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 500}
# 0.813 (+/-0.073) for {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 5}
# 0.835 (+/-0.082) for {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}
# 0.83 (+/-0.04) for {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 250}
# 0.811 (+/-0.03) for {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}
# 0.815 (+/-0.053) for {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 5}
# 0.82 (+/-0.016) for {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}
# 0.811 (+/-0.066) for {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 250}
# 0.805 (+/-0.032) for {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500}
# 0.82 (+/-0.049) for {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 5}
# 0.792 (+/-0.036) for {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}
# 0.794 (+/-0.05) for {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 250}
# 0.796 (+/-0.047) for {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 500}
# 0.801 (+/-0.036) for {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 5}
# 0.783 (+/-0.033) for {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 50}
# 0.798 (+/-0.025) for {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 250}
# 0.798 (+/-0.03) for {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 500}
# 0.818 (+/-0.1) for {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 5}
# 0.83 (+/-0.078) for {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 50}
# 0.828 (+/-0.069) for {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 250}
# 0.818 (+/-0.082) for {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 500}
# 0.82 (+/-0.063) for {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 5}
# 0.8 (+/-0.027) for {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 50}
# 0.805 (+/-0.043) for {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 250}
# 0.801 (+/-0.048) for {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 500}
# 0.801 (+/-0.059) for {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 5}
# 0.8 (+/-0.047) for {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 50}
# 0.798 (+/-0.088) for {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 250}
# 0.801 (+/-0.093) for {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 500}
# 0.792 (+/-0.042) for {'learning_rate': 1, 'max_depth': 7, 'n_estimators': 5}
# 0.796 (+/-0.04) for {'learning_rate': 1, 'max_depth': 7, 'n_estimators': 50}
# 0.788 (+/-0.058) for {'learning_rate': 1, 'max_depth': 7, 'n_estimators': 250}
# 0.796 (+/-0.078) for {'learning_rate': 1, 'max_depth': 7, 'n_estimators': 500}
# 0.772 (+/-0.044) for {'learning_rate': 1, 'max_depth': 9, 'n_estimators': 5}
# 0.783 (+/-0.049) for {'learning_rate': 1, 'max_depth': 9, 'n_estimators': 50}
# 0.794 (+/-0.026) for {'learning_rate': 1, 'max_depth': 9, 'n_estimators': 250}
# 0.792 (+/-0.035) for {'learning_rate': 1, 'max_depth': 9, 'n_estimators': 500}
# 0.204 (+/-0.116) for {'learning_rate': 10, 'max_depth': 1, 'n_estimators': 5}
# 0.204 (+/-0.116) for {'learning_rate': 10, 'max_depth': 1, 'n_estimators': 50}
# 0.204 (+/-0.116) for {'learning_rate': 10, 'max_depth': 1, 'n_estimators': 250}
# 0.204 (+/-0.116) for {'learning_rate': 10, 'max_depth': 1, 'n_estimators': 500}
# 0.311 (+/-0.192) for {'learning_rate': 10, 'max_depth': 3, 'n_estimators': 5}
# 0.311 (+/-0.192) for {'learning_rate': 10, 'max_depth': 3, 'n_estimators': 50}
# 0.311 (+/-0.192) for {'learning_rate': 10, 'max_depth': 3, 'n_estimators': 250}
# 0.311 (+/-0.192) for {'learning_rate': 10, 'max_depth': 3, 'n_estimators': 500}
# 0.464 (+/-0.31) for {'learning_rate': 10, 'max_depth': 5, 'n_estimators': 5}
# 0.442 (+/-0.313) for {'learning_rate': 10, 'max_depth': 5, 'n_estimators': 50}
# 0.506 (+/-0.366) for {'learning_rate': 10, 'max_depth': 5, 'n_estimators': 250}
# 0.5 (+/-0.364) for {'learning_rate': 10, 'max_depth': 5, 'n_estimators': 500}
# 0.61 (+/-0.251) for {'learning_rate': 10, 'max_depth': 7, 'n_estimators': 5}
# 0.597 (+/-0.177) for {'learning_rate': 10, 'max_depth': 7, 'n_estimators': 50}
# 0.579 (+/-0.182) for {'learning_rate': 10, 'max_depth': 7, 'n_estimators': 250}
# 0.605 (+/-0.21) for {'learning_rate': 10, 'max_depth': 7, 'n_estimators': 500}
# 0.713 (+/-0.123) for {'learning_rate': 10, 'max_depth': 9, 'n_estimators': 5}
# 0.712 (+/-0.129) for {'learning_rate': 10, 'max_depth': 9, 'n_estimators': 50}
# 0.693 (+/-0.1) for {'learning_rate': 10, 'max_depth': 9, 'n_estimators': 250}
# 0.719 (+/-0.109) for {'learning_rate': 10, 'max_depth': 9, 'n_estimators': 500}
# 0.376 (+/-0.005) for {'learning_rate': 100, 'max_depth': 1, 'n_estimators': 5}
# 0.376 (+/-0.005) for {'learning_rate': 100, 'max_depth': 1, 'n_estimators': 50}
# 0.376 (+/-0.005) for {'learning_rate': 100, 'max_depth': 1, 'n_estimators': 250}
# 0.376 (+/-0.005) for {'learning_rate': 100, 'max_depth': 1, 'n_estimators': 500}
# 0.29 (+/-0.104) for {'learning_rate': 100, 'max_depth': 3, 'n_estimators': 5}
# 0.29 (+/-0.104) for {'learning_rate': 100, 'max_depth': 3, 'n_estimators': 50}
# 0.29 (+/-0.104) for {'learning_rate': 100, 'max_depth': 3, 'n_estimators': 250}
# 0.29 (+/-0.104) for {'learning_rate': 100, 'max_depth': 3, 'n_estimators': 500}
# 0.369 (+/-0.17) for {'learning_rate': 100, 'max_depth': 5, 'n_estimators': 5}
# 0.375 (+/-0.175) for {'learning_rate': 100, 'max_depth': 5, 'n_estimators': 50}
# 0.365 (+/-0.169) for {'learning_rate': 100, 'max_depth': 5, 'n_estimators': 250}
# 0.378 (+/-0.181) for {'learning_rate': 100, 'max_depth': 5, 'n_estimators': 500}
# 0.543 (+/-0.138) for {'learning_rate': 100, 'max_depth': 7, 'n_estimators': 5}
# 0.567 (+/-0.104) for {'learning_rate': 100, 'max_depth': 7, 'n_estimators': 50}
# 0.59 (+/-0.098) for {'learning_rate': 100, 'max_depth': 7, 'n_estimators': 250}
# 0.558 (+/-0.125) for {'learning_rate': 100, 'max_depth': 7, 'n_estimators': 500}
# 0.669 (+/-0.117) for {'learning_rate': 100, 'max_depth': 9, 'n_estimators': 5}
# 0.65 (+/-0.045) for {'learning_rate': 100, 'max_depth': 9, 'n_estimators': 50}
# 0.695 (+/-0.127) for {'learning_rate': 100, 'max_depth': 9, 'n_estimators': 250}
# 0.663 (+/-0.056) for {'learning_rate': 100, 'max_depth': 9, 'n_estimators': 500}

# %%
joblib.dump(cv.best_estimator_, 'C:/Users/harsh/Desktop/Summer Projects/TitanicKaggle/models/GB_model.pkl')
# Out:
# ['C:/Users/harsh/Desktop/Summer Projects/TitanicKaggle/models/GB_model.pkl']

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score
from time import time

# %%
models = {}

#model name = key, model object = value 
for mdl in ['LR', 'SVM', 'MLP', 'RF', 'GB']:
    models[mdl] = joblib.load('C:/Users/harsh/Desktop/Summer Projects/TitanicKaggle/models/{}_model.pkl'.format(mdl))

# %%
models
# Out:
# {'LR': LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#                     intercept_scaling=1, l1_ratio=None, max_iter=100,
#                     multi_class='warn', n_jobs=None, penalty='l2',
#                     random_state=None, solver='warn', tol=0.0001, verbose=0,
#                     warm_start=False),
#  'SVM': SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#      decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#      kernel='linear', max_iter=-1, probability=False, random_state=None,
#      shrinking=True, tol=0.001, verbose=False),
#  'MLP': MLPClassifier(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#                beta_2=0.999, early_stopping=False, epsilon=1e-08,
#                hidden_layer_sizes=(100, 1), learning_rate='invscaling',
#                learning_rate_init=0.001, max_iter=200, momentum=0.9,
#                n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#                random_state=None, shuffle=True, solver='adam', tol=0.0001,
#                validation_fraction=0.1, verbose=False, warm_start=False),
#  'RF': RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                         max_depth=8, max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, n_estimators=50,
#                         n_jobs=None, oob_score=False, random_state=None,
#                         verbose=0, warm_start=False),
#  'GB': GradientBoostingClassifier(criterion='friedman_mse', init=None,
#                             learning_rate=0.01, loss='deviance', max_depth=3,
#                             max_features=None, max_leaf_nodes=None,
#                             min_impurity_decrease=0.0, min_impurity_split=None,
#                             min_samples_leaf=1, min_samples_split=2,
#                             min_weight_fraction_leaf=0.0, n_estimators=500,
#                             n_iter_no_change=None, presort='auto',
#                             random_state=None, subsample=1.0, tol=0.0001,
#                             validation_fraction=0.1, verbose=0,
#                             warm_start=False)}

# %%
def evaluate_model(name, model, features, labels):
    start = time()
    pred = model.predict(features)
    end = time()
    accuracy = round(accuracy_score(labels, pred), 3)
    precision = round(precision_score(labels, pred), 3)
    recall = round(recall_score(labels, pred), 3)
    
    print('{} -- Accuracy: {} / Precision: {} / Recall: {} / Latency: {}ms'.format(name, 
                                                                                  accuracy, precision, recall, 
                                                                                  round((end - start), 3)))

# %%
for name, mdl in models.items():
    evaluate_model(name, mdl, x_val, y_val)
# Out:
# LR -- Accuracy: 0.77 / Precision: 0.707 / Recall: 0.631 / Latency: 0.001ms
# SVM -- Accuracy: 0.747 / Precision: 0.672 / Recall: 0.6 / Latency: 0.002ms
# MLP -- Accuracy: 0.764 / Precision: 0.689 / Recall: 0.646 / Latency: 0.001ms
# RF -- Accuracy: 0.815 / Precision: 0.796 / Recall: 0.662 / Latency: 0.008ms
# GB -- Accuracy: 0.815 / Precision: 0.808 / Recall: 0.646 / Latency: 0.002ms

# %%
#best model = GradientBoosting 
joblib.dump(models.get('GB'), 'C:/Users/harsh/Desktop/Summer Projects/TitanicKaggle/models/BEST_model.pkl')
# Out:
# ['C:/Users/harsh/Desktop/Summer Projects/TitanicKaggle/models/BEST_model.pkl']

# %%
testdf.head()
# Out:
#    Pclass  Sex   Age  Relatives  Cabin_ind     Fare
# 0       3    0  34.5          0          0   7.8292
# 1       3    1  47.0          1          0   7.0000
# 2       2    0  62.0          0          0   9.6875
# 3       3    0  27.0          0          0   8.6625
# 4       3    1  22.0          2          0  12.2875

# %%
testdf.reindex(pd.Series(range(892, 1310)), axis)
# Out:
#       Pclass  Sex  Age  Relatives  Cabin_ind  Fare
# 892      NaN  NaN  NaN        NaN        NaN   NaN
# 893      NaN  NaN  NaN        NaN        NaN   NaN
# 894      NaN  NaN  NaN        NaN        NaN   NaN
# 895      NaN  NaN  NaN        NaN        NaN   NaN
# 896      NaN  NaN  NaN        NaN        NaN   NaN
# 897      NaN  NaN  NaN        NaN        NaN   NaN
# 898      NaN  NaN  NaN        NaN        NaN   NaN
# 899      NaN  NaN  NaN        NaN        NaN   NaN
# 900      NaN  NaN  NaN        NaN        NaN   NaN
# 901      NaN  NaN  NaN        NaN        NaN   NaN
# 902      NaN  NaN  NaN        NaN        NaN   NaN
# 903      NaN  NaN  NaN        NaN        NaN   NaN
# 904      NaN  NaN  NaN        NaN        NaN   NaN
# 905      NaN  NaN  NaN        NaN        NaN   NaN
# 906      NaN  NaN  NaN        NaN        NaN   NaN
# 907      NaN  NaN  NaN        NaN        NaN   NaN
# 908      NaN  NaN  NaN        NaN        NaN   NaN
# 909      NaN  NaN  NaN        NaN        NaN   NaN
# 910      NaN  NaN  NaN        NaN        NaN   NaN
# 911      NaN  NaN  NaN        NaN        NaN   NaN
# 912      NaN  NaN  NaN        NaN        NaN   NaN
# 913      NaN  NaN  NaN        NaN        NaN   NaN
# 914      NaN  NaN  NaN        NaN        NaN   NaN
# 915      NaN  NaN  NaN        NaN        NaN   NaN
# 916      NaN  NaN  NaN        NaN        NaN   NaN
# 917      NaN  NaN  NaN        NaN        NaN   NaN
# 918      NaN  NaN  NaN        NaN        NaN   NaN
# 919      NaN  NaN  NaN        NaN        NaN   NaN
# 920      NaN  NaN  NaN        NaN        NaN   NaN
# 921      NaN  NaN  NaN        NaN        NaN   NaN
# ...      ...  ...  ...        ...        ...   ...
# 1280     NaN  NaN  NaN        NaN        NaN   NaN
# 1281     NaN  NaN  NaN        NaN        NaN   NaN
# 1282     NaN  NaN  NaN        NaN        NaN   NaN
# 1283     NaN  NaN  NaN        NaN        NaN   NaN
# 1284     NaN  NaN  NaN        NaN        NaN   NaN
# 1285     NaN  NaN  NaN        NaN        NaN   NaN
# 1286     NaN  NaN  NaN        NaN        NaN   NaN
# 1287     NaN  NaN  NaN        NaN        NaN   NaN
# 1288     NaN  NaN  NaN        NaN        NaN   NaN
# 1289     NaN  NaN  NaN        NaN        NaN   NaN
# 1290     NaN  NaN  NaN        NaN        NaN   NaN
# 1291     NaN  NaN  NaN        NaN        NaN   NaN
# 1292     NaN  NaN  NaN        NaN        NaN   NaN
# 1293     NaN  NaN  NaN        NaN        NaN   NaN
# 1294     NaN  NaN  NaN        NaN        NaN   NaN
# 1295     NaN  NaN  NaN        NaN        NaN   NaN
# 1296     NaN  NaN  NaN        NaN        NaN   NaN
# 1297     NaN  NaN  NaN        NaN        NaN   NaN
# 1298     NaN  NaN  NaN        NaN        NaN   NaN
# 1299     NaN  NaN  NaN        NaN        NaN   NaN
# 1300     NaN  NaN  NaN        NaN        NaN   NaN
# 1301     NaN  NaN  NaN        NaN        NaN   NaN
# 1302     NaN  NaN  NaN        NaN        NaN   NaN
# 1303     NaN  NaN  NaN        NaN        NaN   NaN
# 1304     NaN  NaN  NaN        NaN        NaN   NaN
# 1305     NaN  NaN  NaN        NaN        NaN   NaN
# 1306     NaN  NaN  NaN        NaN        NaN   NaN
# 1307     NaN  NaN  NaN        NaN        NaN   NaN
# 1308     NaN  NaN  NaN        NaN        NaN   NaN
# 1309     NaN  NaN  NaN        NaN        NaN   NaN
#
# [418 rows x 6 columns]

# %%
test_pred = models.get('GB').predict(testdf)
test_pred
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-9ff25038ed29> in <module>
# ----> 1 test_pred = models.get('GB').predict(testdf)
#       2 test_pred
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\gradient_boosting.py in predict(self, X)
#    2131             The predicted values.
#    2132         """
# -> 2133         raw_predictions = self.decision_function(X)
#    2134         encoded_labels = \
#    2135             self.loss_._raw_prediction_to_decision(raw_predictions)
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\gradient_boosting.py in decision_function(self, X)
#    2086             array of shape [n_samples].
#    2087         """
# -> 2088         X = check_array(X, dtype=DTYPE, order="C", accept_sparse='csr')
#    2089         raw_predictions = self._raw_predict(X)
#    2090         if raw_predictions.shape[1] == 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     540         if force_all_finite:
#     541             _assert_all_finite(array,
# --> 542                                allow_nan=force_all_finite == 'allow-nan')
#     543
#     544     if ensure_min_samples > 0:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57     # for object dtype data, we only check for NaNs (GH-13254)
#      58     elif X.dtype == np.dtype('object') and not allow_nan:
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
pred = dataset = pd.DataFrame({'PassengerId': list(testdf.index), 
                               'Survived': list(test_pred)}, columns=['PassengerId', 'Survived'])

# %%
pred.head()

# %%
export_csv = pred.to_csv (r'C:\Users\harsh\Desktop\Summer Projects\TitanicKaggle\predictions2.csv', index = None, header=True)
